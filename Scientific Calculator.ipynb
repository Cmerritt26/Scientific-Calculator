# %%
class Scientific_Calculator():
    def __init__(self, input1, input2):
        self.input1= input1
        self.input2= input2
        
    def addition(num1, num2):
        print("Addition", self.number1+self.number2)
    
    def subtraction(num1, num2):
        print("Subtraction", num1-num2)
    
    def multiplication(num1, num2):
        print("Multiplication: ", num1*num2)
        
    def division(num1, num2):
        print("Division", num1/num2)
    
    def sqrt(num1):
        print("Sqrt: ", math.sqrt(num1))
    
    def log10(num1):
        print("log10: ", math.log10(num1))
    
    def sin(num1):
        print("sin: ", math.sin(num1))
        
    def cos(num1):
        print("cos: ", math.cos(num1))
        
    def log(num1):
        print("log: ", math.log(num1))
    
    def acos(num1):
        print("acos: ", math.acos(num1))
    
    def asin(num1):
        if num1 < -1 or num1 > 1:
            print("Input must be in the range [-1, 1] for arcsine.")
        else:
            print("asin:", math.asin(num1))
    
    def tan(num1):
        print("tan: ", math.tan(num1))
        
    def ceil(num1):
        print("ceil: ", math.ceil(num1))
        
    def floor(num1):
        print("floor: ", math.floor(num1))
        
    def degrees(num1):
        print("degrees: ", math.degrees(num1))
    
    def log2(num1):
        print("log2: ", math.log2(num1))
        
    def cosh(num1):
        print("cosh: ", math.cosh(num1))
        
    def atan(num1):
        print("atan: ", math.atan(num1))
        
    def isqrt(num1):
        print("isqrt: ", math.isqrt(num1))
        
while True:
    print("Select a number: ")
    print("1: Addition")
    print("2: Subtraction")
    print("3: Multiplication")
    print("4: Division")
    print("5: Sqrt")
    print("6: log10")
    print("7: sin")
    print("8: cos")
    print("9: log")
    print("10: acos")
    print("11: asin")
    print("12: tan")
    print("13: ceil")
    print("14: floor")
    print("15: degrees")
    print("16: log2")
    print("17: cosh")
    print("18: atan")
    print("19: isqrt")
    print("20: exit")
    choice= int(input("Enter your choice(1-20):"))
    
    if choice==1:
        num1=int(input("Enter the first number: "))
        num2=int(input("Enter the second number: "))
        Scientific_Calculator.addition(num1, num2)
    elif choice==2:
        num1=int(input("Enter the first number: "))
        num2=int(input("Enter the second number: "))
        Scientific_Calculator.subtraction(num1, num2)
    elif choice==3:
        num1=int(input("Enter the first number: "))
        num2=int(input("Enter the second number: "))
        Scientific_Calculator.multiplication(num1, num2)
    elif choice==4:
        num1=int(input("Enter the first number: "))
        num2=int(input("Enter the second number: "))
        if num2==0:
                print("Infinity")
        else:
            Scientific_Calculator.division(num1, num2)
    elif choice==5:
        num1=int(input("Enter the number: "))
        Scientific_Calculator.sqrt(num1)
    elif choice==6:
        num1=int(input("Enter the number: "))
        Scientific_Calculator.log10(num1)
    elif choice==7:
        num1=int(input("Enter the number: "))
        Scientific_Calculator.sin(num1)
    elif choice==8:
        num1=int(input("Enter the number: "))
        Scientific_Calculator.cos(num1)
    elif choice==9:
        num1=int(input("Enter the number: "))
        Scientific_Calculator.log(num1)
    elif choice==10:
        num1=float(input("Enter the number: "))
        Scientific_Calculator.acos(num1)
    elif choice==11:
        num1=float(input("Enter the number: "))
        Scientific_Calculator.asin(num1)
    elif choice==12:
        num1=int(input("Enter the number: "))
        Scientific_Calculator.tan(num1)
    elif choice==13:
        num1=int(input("Enter the number: "))
        Scientific_Calculator.ceil(num1)
    elif choice==14:
        num1=int(input("Enter the number: "))
        Scientific_Calculator.floor(num1)
    elif choice==15:
        num1=int(input("Enter the number: "))
        Scientific_Calculator.degrees(num1)
    elif choice==16:
        num1=int(input("Enter the number: "))
        Scientific_Calculator.log2(num1)
    elif choice==17:
        num1=int(input("Enter the number: "))
        Scientific_Calculator.cosh(num1)
    elif choice==18:
        num1=int(input("Enter the number: "))
        Scientific_Calculator.atan(num1)
    elif choice==19:
        num1=int(input("Enter the number: "))
        Scientific_Calculator.isqrt(num1)
    elif choice==20:
        break
    else:
        print("Wrong choice. Choose a number between (1-20)")
# Out:
# Select a number:
# 1: Addition
# 2: Subtraction
# 3: Multiplication
# 4: Division
# 5: Sqrt
# 6: log10
# 7: sin
# 8: cos
# 9: log
# 10: acos
# 11: asin
# 12: tan
# 13: ceil
# 14: floor
# 15: degrees
# 16: log2
# 17: cosh
# 18: atan
# 19: isqrt
# 20: exit
# Enter your choice(1-20):20

# %%
dir(math)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %%
import math
